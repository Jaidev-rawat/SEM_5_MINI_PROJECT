# %% [markdown]
# ### Code Run on Google Colab to download data from kaggle to google drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#attaching kaggle key location
import os
os.environ['KAGGLE_CONFIG_DIR']='/content/gdrive/MyDrive/kaggle'

# %%
# %cd /content/gdrive/MyDrive/kaggle
# Out:
# /content/gdrive/MyDrive/kaggle

# %%
ls
# Out:
# food20dataset1/              indianfoodclassification/
# indiafood21categoriessmall/  indian-food-images-dataset/
# indian-food/                 kaggle.json

# %%
# !kaggle datasets download -d cdart99/food20dataset  #first data set downloaded
# Out:
# ...
#  98% 425M/435M [00:08<00:00, 59.0MB/s]
# 100% 435M/435M [00:08<00:00, 52.7MB/s]

# %%
 # !mkdir food20dataset1
 # !mv food20dataset.zip food20dataset1  #moving to new folder

# %%
# %cd food20dataset1
# Out:
# /content/gdrive/My Drive/kaggle/food20dataset1

# %%
ls
# Out:
# food20dataset.zip

# %%
# !unzip food20dataset.zip  #unzip

# %%
ls
# Out:
# food20dataset/  food20dataset.zip

# %%
# %cd ..
# Out:
# /content/gdrive/My Drive/kaggle

# %%
ls
# Out:
# food20dataset1/  kaggle.json

# %%
# !kaggle datasets download -d iamsouravbanerjee/indian-food-images-dataset  #2nd data set downloaded
# Out:
# ...
# 100% 354M/354M [00:04<00:00, 112MB/s]

# %%
# !unzip indian-food-images-dataset.zip

# %%
ls
# Out:
# food20dataset1/  indian-food-images-dataset/  kaggle.json

# %%
 # !kaggle datasets download -d sandy1112/indiafood21categoriessmall
 # !mkdir indiafood21categoriessmall
 # !mv indiafood21categoriessmall.zip indiafood21categoriessmall
 # %cd indiafood21categoriessmall
 # !unzip indiafood21categoriessmall.zip

# %%
 
 # !mkdir indianfoodclassification
 # !mv indian-food-classification.zip indianfoodclassification
 # %cd indianfoodclassification
 # !unzip indian-food-classification.zip

# %%
ls
# Out:
# food20dataset1/              indianfoodclassification/    kaggle.json
# indiafood21categoriessmall/  indian-food-images-dataset/

# %%
 # !kaggle datasets download -d manoj1998/indian-food
 # !mkdir indian-food
 # !mv indian-food.zip indian-food
 # %cd indian-food
 # !unzip indian-food.zip
# Out:
# ...
#  96% 189M/196M [00:02<00:00, 77.0MB/s]
# 100% 196M/196M [00:02<00:00, 90.5MB/s]
# /content/gdrive/My Drive/kaggle/indian-food
# Archive:  indian-food.zip
#   inflating: food/test/eggs/IMG-20200614-WA0127.jpg
#   inflating: food/test/eggs/IMG-20200614-WA0128.jpg
#   inflating: food/test/eggs/IMG-20200614-WA0129.jpg
#   inflating: food/test/eggs/IMG-20200614-WA0130.jpg
#   inflating: food/test/eggs/IMG-20200614-WA0131.jpg
#   inflating: food/test/eggs/IMG-20200614-WA0132.jpg
#   inflating: food/test/eggs/IMG-20200614-WA0133.jpg
#   inflating: food/test/eggs/IMG-20200614-WA0134.jpg
#   inflating: food/test/eggs/IMG-20200614-WA0135.jpg
#   inflating: food/test/eggs/IMG-20200614-WA0136.jpg
#   inflating: food/test/eggs/IMG-20200614-WA0137.jpg
#   inflating: food/test/eggs/IMG-20200614-WA0138.jpg
#   inflating: food/test/eggs/IMG-20200614-WA0139.jpg
#   inflating: food/test/eggs/IMG-20200614-WA0140.jpg
#   inflating: food/test/eggs/IMG-20200614-WA0141.jpg
# ...

# %%
 # !kaggle datasets download -d ashish369/indian-food-32
 # !mkdir indian_food_32
 # !mv indian-food-32.zip indian_food_32
 # %cd indian_food_32
 # !unzip indian-food-32.zip
